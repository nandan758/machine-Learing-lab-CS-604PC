# %% [markdown]
# <a href="https://colab.research.google.com/github/nandan758/machine-Learing-lab-CS-604PC/blob/main/MLPROG2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2.Study of python basic libraries
import math

num = 9
angle_degrees = 45

print("Square Root:", math.sqrt(num))
print("Factorial:", math.factorial(5))
print("Logarithm base 10:", math.log10(100))
print("Sine of 45 degrees:", math.sin(math.radians(angle_degrees)))
print("Value of Pi:", math.pi)
